# %%
import numpy as np
import pandas as pd

from scipy.stats import mode

import warnings
warnings.filterwarnings('ignore')

# %%
DATASET_PATH = './csv/housing.csv'
PREPARED_DATASET_PATH = './csv/housing_prepared.csv'

# %%
pd.read_csv??

# %%
df = pd.read_csv(DATASET_PATH, sep=',')
df.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
#
#    id
# 0   0
# 1   1
# 2   2
# 3   3

# %%
df.tail(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity     id
# 20638          INLAND  20638
# 20639          INLAND  20639

# %%
df.sample(3)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9877     -121.85     36.61                38.0        238.0             NaN
# 19718    -121.83     39.23                25.0       3819.0           702.0
# 870      -121.93     37.49                 5.0       1150.0           311.0
#
#        population  households  median_income  median_house_value  \
# 9877        191.0        67.0         1.3897            125000.0
# 19718      1983.0       658.0         2.4464             72500.0
# 870         648.0       245.0         3.5714            300000.0
#
#       ocean_proximity     id
# 9877        <1H OCEAN   9877
# 19718          INLAND  19718
# 870         <1H OCEAN    870

# %%
df.sample(frac=0.0001)  # frac - share
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19259    -122.74     38.45                17.0       3064.0           588.0
# 12874    -121.36     38.67                 5.0       5819.0          1507.0
#
#        population  households  median_income  median_house_value  \
# 19259      1704.0       590.0         3.9329            170900.0
# 12874      3237.0      1356.0         2.2339            116600.0
#
#       ocean_proximity     id
# 19259       <1H OCEAN  19259
# 12874          INLAND  12874
