# %%
# 1) epoch = 1 forward & backward pass of ALL training samples
# 2) batch_size = number of training samples in one forward & backward pass
# 3) number of iterations = number of passes, each pass using [batch_size] number of samples
# Example: 100 samples, batch_size = 2 => 100/20 = 5 => 5 iterations for 1 epoch

# %%
import numpy as np
import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
import math
from decimal import Decimal as D

# %%
class WineDataset(Dataset):
    def __init__(self):
        # data load
        xy = np.loadtxt('data/wine.csv', delimiter=',', dtype=np.float32, skiprows=1)
        self.x = torch.from_numpy(xy[:, 1:])
        self.y = torch.from_numpy(xy[:, [0]])  # [n_samples, 1 col]
        self.n_samples = xy.shape[0]

    def __getitem__(self, index):
        # dataset[0]
        return self.x[index], self.y[index]

    def __len__(self):
        # len(dataset)
        return self.n_samples

# %%
dataset = WineDataset()
len(dataset)
# Out:
# 178

# %%
first_data = dataset[0]
feature, labels = first_data
display(feature, labels)
# Out:
# tensor([1.4230e+01, 1.7100e+00, 2.4300e+00, 1.5600e+01, 1.2700e+02, 2.8000e+00,
#         3.0600e+00, 2.8000e-01, 2.2900e+00, 5.6400e+00, 1.0400e+00, 3.9200e+00,
#         1.0650e+03])
# tensor([1.])

# %%
data_loader = DataLoader(dataset=dataset, batch_size=4, shuffle=True)
#data_titer = iter(data_loader)
#data = next(data_titer)
#feature, labels = data
#display(feature, labels)

# %%
# training loop
n_epochs = 2
total_samples = len(dataset)  # number of rows
batch_size = 4
n_iters = math.ceil(total_samples / batch_size)  # number of rows / number of rows in batch
total_samples, n_iters
# Out:
# (178, 45)

# %%
for epoch in range(n_iters):
    for i, (inputs, labels) in enumerate(data_loader):
        # forward pass
        # loss & optimizer
        # backward pass
        # update weights
        if (i + 1) % 5 == 0:
            print(f'Epoch: {epoch+1}/{n_epochs}, step: {i+1}/{n_iters}, inputs {inputs.shape}')
# Out:
# Epoch: 1/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 1/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 2/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 2/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 3/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 3/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 4/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 4/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 5/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 5/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 6/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 6/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 7/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 7/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 8/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 8/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 9/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 9/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 10/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 10/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 11/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 11/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 12/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 12/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 13/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 13/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 14/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 14/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 15/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 15/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 16/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 16/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 17/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 17/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 18/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 18/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 19/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 19/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 20/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 20/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 21/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 21/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 22/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 22/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 23/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 23/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 24/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 24/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 25/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 25/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 26/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 26/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 27/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 27/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 28/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 28/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 29/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 29/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 30/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 30/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 31/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 31/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 32/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 32/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 33/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 33/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 34/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 34/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 35/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 35/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 36/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 36/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 37/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 37/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 38/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 38/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 39/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 39/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 40/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 40/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 41/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 41/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 42/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 42/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 43/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 43/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 44/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 44/2, step: 45/45, inputs torch.Size([2, 13])
# Epoch: 45/2, step: 5/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 10/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 15/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 20/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 25/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 30/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 35/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 40/45, inputs torch.Size([4, 13])
# Epoch: 45/2, step: 45/45, inputs torch.Size([2, 13])

# %%
# examples of datasets in torchvision

# torchvision.datasets.MNIST()
# torchvision.datasets.fashion-mnist()
# torchvision.datasets.cifar()
# torchvision.datasets.coco()
