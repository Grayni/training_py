# %%
import torch

# %%
x = torch.randn([1, 100, 3])
x
# Out:
# tensor([[[ 0.1886, -1.9313,  0.4641],
#          [ 0.2014,  1.4163,  0.3644],
#          [ 0.5420, -0.5078, -0.6814],
#          [ 1.0743, -0.2754, -0.7268],
#          [ 2.1418, -0.3118, -0.9626],
#          [-0.6959, -0.5682,  0.6131],
#          [ 0.1704,  0.3047,  0.0907],
#          [-2.5671, -1.1497, -1.0126],
#          [-1.5670,  0.4291,  0.3933],
#          [ 0.4028,  0.3603, -1.1063],
#          [-1.1847, -0.3725, -1.4269],
#          [-1.5416,  0.0916, -1.4121],
#          [-1.7325,  1.1106,  0.1059],
#          [-0.2482,  0.0446, -0.0752],
#          [ 1.0771,  0.2439, -0.1640],
#          [-0.8642,  1.2327, -1.2407],
#          [-1.1373, -0.7371, -0.9571],
#          [ 0.2219, -0.5558, -0.6385],
#          [-0.7771, -1.3614,  0.3535],
#          [-0.5261, -0.7367,  0.5674],
#          [ 0.1557, -2.3513,  1.4731],
#          [ 2.2819,  1.8996, -0.3253],
#          [-0.2503,  0.6653,  0.1656],
#          [ 0.2045, -1.2054,  1.3440],
#          [-0.7550,  1.2551, -1.4434],
#          [ 1.2443,  0.3172, -1.8432],
#          [-0.6777, -0.1702,  0.5381],
#          [-1.0096, -0.5155, -0.2128],
#          [-0.2968, -0.4498, -1.1088],
#          [ 0.8515, -1.8103,  0.3082],
#          [ 0.4089,  0.0639, -0.7597],
#          [-0.0203, -0.9541, -1.0195],
#          [ 0.2148, -0.1127, -0.9967],
#          [ 0.5992,  0.8429,  1.3657],
#          [-0.5950,  0.9533, -0.4704],
#          [-0.3596, -0.2470, -0.5333],
#          [ 2.3006, -0.6824, -1.0363],
#          [ 1.0290,  0.6766,  1.6678],
#          [-1.0128, -1.9915, -1.8286],
#          [-0.7436, -1.2807, -1.4639],
#          [ 1.8714,  0.7030,  0.2647],
#          [ 0.9438,  0.1693,  0.0577],
#          [-0.5387,  0.2257,  1.1152],
#          [-0.7213, -1.3224, -1.9547],
#          [-1.0510, -2.0201, -1.7358],
#          [ 0.5457,  1.4739, -0.3088],
#          [ 0.7978,  0.3747,  0.6605],
#          [-2.1236, -0.6880,  0.0593],
#          [ 0.0671, -0.2988, -1.5456],
#          [ 0.9152, -0.2218,  0.0260],
#          [-1.1525, -0.3154,  0.9449],
#          [ 0.1261, -0.5253,  1.2757],
#          [-0.6299, -0.8443, -0.4102],
#          [-1.9413, -2.3715,  1.0513],
#          [-1.3558,  1.1882, -0.1895],
#          [-0.2039, -1.0587, -1.5235],
#          [ 0.3156,  2.1600,  1.0193],
#          [-0.8017, -0.6619,  0.4072],
#          [ 2.0525,  0.6077, -0.5198],
#          [-0.9818, -0.9348,  2.0427],
#          [-1.7468, -0.3332, -1.9968],
#          [ 1.3563, -1.3720,  0.8617],
#          [ 1.6258,  0.7659,  0.0403],
#          [ 0.6952, -0.9096,  0.0323],
#          [-1.3553, -1.8200,  0.8136],
#          [ 0.4983, -0.2881,  0.2159],
#          [ 0.7198, -0.2217, -0.6121],
#          [ 0.9181, -0.2117,  1.2169],
#          [ 0.5176,  0.2848,  0.9757],
#          [ 0.3035, -0.7093, -1.1678],
#          [-0.8909, -0.2680,  1.8343],
#          [ 0.1853, -1.1049, -0.3210],
#          [ 0.2600, -1.9976,  0.4861],
#          [ 1.2534,  0.3876,  0.6003],
#          [-1.4398,  0.1300,  0.7115],
#          [-1.5796, -1.2806,  1.0266],
#          [-0.0517,  0.9670,  0.3187],
#          [-0.5523, -1.8662,  0.4714],
#          [-2.7990,  0.6226,  0.5600],
#          [-1.2289,  0.9292,  0.1448],
#          [-0.8882, -0.9350,  0.8147],
#          [ 0.5740,  1.2362,  0.0173],
#          [-1.3039, -0.2028, -0.8342],
#          [-1.1488, -0.0631, -2.2673],
#          [ 0.7020, -0.2413, -0.4868],
#          [ 0.2486, -1.3807, -0.5788],
#          [-1.6649, -1.3412,  1.6668],
#          [-0.8510,  0.1168, -0.2397],
#          [-0.6519, -1.1722, -0.2559],
#          [ 1.0817,  0.4372,  0.9078],
#          [ 0.7228,  0.6574,  0.2685],
#          [-1.6491, -0.9199,  0.9953],
#          [ 0.0778, -0.4310,  0.1724],
#          [ 0.9824, -1.0312,  0.3631],
#          [-1.4335,  0.9054,  1.2418],
#          [-0.8830,  0.4441, -0.8436],
#          [-0.4436, -0.1696,  0.8426],
#          [-1.1333, -0.6569, -1.6667],
#          [-0.4677, -0.8401, -1.5210],
#          [ 0.0177, -0.1827,  1.0155]]])

# %%
target = torch.randn([1, 100, 64])
target
# Out:
# tensor([[[-0.4358, -1.3479,  0.8358,  ...,  0.2478, -0.9059, -0.5684],
#          [-1.6908, -1.0111, -0.2906,  ..., -0.5051,  0.2567, -1.9523],
#          [ 0.1445, -0.0155,  0.4045,  ..., -1.7331, -0.4210,  0.2701],
#          ...,
#          [ 0.0789,  0.8596,  1.9881,  ..., -0.6076,  0.6359,  0.1348],
#          [ 0.5301, -0.7586,  0.6715,  ...,  0.7232, -1.2076, -1.3507],
#          [ 0.8830, -0.7228, -1.5907,  ..., -0.8787,  0.3828,  1.4236]]])

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(3, 64)  # w*x+b, w - weight, b - bias

    def forward(self, x):  # __call__ -> forward()
        x = self.fc1(x)
        return x

# %%
model = Net()

# %%
model(x)
# Out:
# tensor([[[ 1.1106,  0.3220,  0.4648,  ..., -0.5395, -0.0068, -0.2968],
#          [-0.4575, -0.5705, -0.3382,  ...,  0.4390, -0.7644,  0.2331],
#          [ 0.9963,  0.2057,  0.0534,  ..., -0.7729, -0.1326, -0.3513],
#          ...,
#          [ 1.7822, -0.4386, -0.0107,  ..., -0.2880,  0.2617, -1.4483],
#          [ 1.7190, -0.0941,  0.0554,  ..., -0.6564,  0.2123, -1.1476],
#          [-0.0122, -0.2823,  0.0839,  ...,  0.3198, -0.5111,  0.1383]]],
#        grad_fn=<ViewBackward0>)

# %%
model(x).shape
# Out:
# torch.Size([1, 100, 64])

# %%
criterion = torch.nn.MSELoss()

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.0003)

# %%
output = model(x)

# %% [markdown]
# ### Loss

# %%
loss = criterion(output, target)

# %%
print(loss.item())
# Out:
# 1.4128917455673218

# %%
torch.sum((output - target)**2)/6400
# Out:
# tensor(1.4129, grad_fn=<DivBackward0>)

# %%
for epoch in range(10):
    output = model(x)
    loss = criterion(output, target)
    print('Epoch: ', epoch, 'Loss: ', loss.item())
    optimizer.zero_grad()  # w.grad, b.grad - reset to zero
    loss.backward()  # update w.grad, b.grad
    optimizer.step()
# Out:
# Epoch:  0 Loss:  1.4129834175109863
# Epoch:  1 Loss:  1.412974238395691
# Epoch:  2 Loss:  1.4129650592803955
# Epoch:  3 Loss:  1.4129558801651
# Epoch:  4 Loss:  1.4129468202590942
# Epoch:  5 Loss:  1.4129375219345093
# Epoch:  6 Loss:  1.4129283428192139
# Epoch:  7 Loss:  1.4129191637039185
# Epoch:  8 Loss:  1.412909984588623
# Epoch:  9 Loss:  1.4129008054733276

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.1108, -0.4839, -0.5358],
#          [ 0.4631, -0.2711, -0.0925],
#          [ 0.0186, -0.2379,  0.0693],
#          [-0.1824, -0.3259,  0.4563],
#          [-0.2399,  0.2391,  0.2108],
#          [ 0.4658,  0.0530,  0.3135],
#          [-0.2289,  0.4873, -0.2183],
#          [ 0.0676, -0.2338, -0.5768],
#          [-0.4936,  0.2793,  0.2278],
#          [ 0.0121,  0.4278,  0.5225],
#          [ 0.4636,  0.0181,  0.3542],
#          [-0.0743, -0.1652,  0.4555],
#          [-0.5748,  0.3301, -0.1855],
#          [ 0.4070, -0.0157,  0.2231],
#          [-0.5392, -0.0966,  0.5703],
#          [-0.5713, -0.4461, -0.3337],
#          [-0.5467,  0.4507, -0.3565],
#          [-0.4622, -0.1913,  0.3445],
#          [-0.0410,  0.0660, -0.3433],
#          [-0.1777, -0.3218,  0.5148],
#          [ 0.1953,  0.1761, -0.2110],
#          [ 0.0536, -0.4375,  0.1953],
#          [ 0.1947,  0.0492,  0.4788],
#          [-0.2869, -0.0300,  0.2454],
#          [-0.4383,  0.0014,  0.4209],
#          [ 0.3826,  0.1925, -0.4315],
#          [ 0.0759, -0.3520, -0.1113],
#          [ 0.1887,  0.1288,  0.1463],
#          [-0.5189,  0.4413, -0.0661],
#          [-0.3728, -0.2203,  0.5746],
#          [-0.5771, -0.4359,  0.2437],
#          [-0.0652, -0.1676, -0.0798],
#          [-0.4878,  0.1529,  0.4090],
#          [ 0.0701,  0.3375, -0.3371],
#          [ 0.2837, -0.2868, -0.5601],
#          [ 0.0725, -0.4566, -0.4811],
#          [-0.5525,  0.3871, -0.3675],
#          [ 0.0966, -0.0252, -0.0153],
#          [-0.0153, -0.3028, -0.3290],
#          [ 0.0901,  0.3688, -0.1117],
#          [-0.4520,  0.4108,  0.1442],
#          [-0.0897,  0.4248, -0.0297],
#          [ 0.5689, -0.5351, -0.5152],
#          [-0.1497,  0.0121, -0.0910],
#          [-0.4394, -0.2283,  0.0916],
#          [-0.1255,  0.3263, -0.0138],
#          [-0.3062,  0.1999,  0.1447],
#          [-0.4312,  0.2400,  0.3827],
#          [-0.5484,  0.4284, -0.2662],
#          [ 0.4932,  0.0684, -0.1167],
#          [ 0.0737,  0.2426, -0.1258],
#          [ 0.2287,  0.1548, -0.2440],
#          [-0.4197,  0.2075, -0.2607],
#          [-0.3080,  0.3988, -0.2127],
#          [ 0.2314, -0.1629,  0.4477],
#          [ 0.3823,  0.0338, -0.0856],
#          [-0.3843, -0.2365,  0.0944],
#          [-0.0559,  0.2751,  0.0093],
#          [-0.4827,  0.4481,  0.3571],
#          [-0.1841,  0.2299, -0.4222],
#          [-0.2297, -0.1998,  0.2533],
#          [-0.5593,  0.3067,  0.4124],
#          [-0.0928, -0.2321, -0.2073],
#          [ 0.4138,  0.1681,  0.3841]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.4455, -0.2461, -0.0303, -0.5453, -0.1002,  0.4113, -0.0312, -0.1233,
#          -0.1075,  0.4195, -0.5581,  0.0779, -0.3162,  0.2320, -0.0090, -0.5719,
#           0.1193,  0.3348,  0.1514,  0.1766, -0.0582, -0.5139, -0.1846, -0.3295,
#          -0.3345, -0.4867,  0.4820, -0.2928, -0.1614, -0.5056,  0.0726, -0.3636,
#          -0.2600, -0.2584,  0.1547,  0.2177, -0.2312,  0.2615,  0.0314,  0.2989,
#           0.4938,  0.4988,  0.3617,  0.0049,  0.0451, -0.3584, -0.4807, -0.4159,
#          -0.1839,  0.4490,  0.5346,  0.0899,  0.4551,  0.5707,  0.4739,  0.2143,
#           0.3355,  0.4824, -0.1368,  0.4567,  0.2568, -0.0330, -0.3414, -0.2284],
#         requires_grad=True)]
