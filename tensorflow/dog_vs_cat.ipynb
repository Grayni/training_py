# %%
import pandas as pd
import numpy as np
import cv2
import tensorflow.keras.models as M
import tensorflow.keras.layers as L
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import clear_output
import keras

# %%
image=Image.open('./datasets/dog_vs_cat/training_set/dogs/dog.5.jpg')
image=image.convert('L')
image=np.array(image)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# #### histogram

# %%
a,b,x=plt.hist(image.flatten())

# %%
def get_threshold(image) :
    a,b,x=plt.hist(image.flatten())
    arg=np.argmax(a)
    threshold=[b[arg],b[arg+1]]
    plt.clf()
    return threshold
def make_mask(path,color='blue',print_plot=False):
    image=Image.open(path)
    image=image.resize((150,150))
    image=image.convert('L')
    image=np.array(image)
    threshold=get_threshold(image)
    if color=='blue' :
        n=[0,0,255]
    masked_image=[]
    for i in image.flatten() :
        if i >= threshold[0] and i<=threshold[1] :
            masked_image.append(255)
        else:
            masked_image.append(0)
    masked_image=np.array(masked_image)
    masked_image=masked_image.reshape(image.shape)
    if print_plot==True :
        plt.imshow(masked_image)
    return masked_image

# %%
arr=make_mask('./datasets/dog_vs_cat/training_set/dogs/dog.1001.jpg',print_plot=True)

# %% [markdown]
# #### Masked Data

# %%
# Adding the paths
dog_path='./datasets/dog_vs_cat/training_set/dogs'
cats_path='./datasets/dog_vs_cat/training_set/cats'

# %%
# Making the data
X=[]
y=[]
count=0
for i in os.listdir(dog_path)[:1000]:
    print(count*100/1000)
    clear_output(wait=True)
    count+=1
    X.append(make_mask(dog_path+'/'+i))

y=[1]*1000

# %%
# Making mask image data for cats
x2=[]
y2=[]
count=0
for i in os.listdir(cats_path)[:1000]:
    print(count*100/1000)
    clear_output(wait=True)
    count+=1
    x2.append(make_mask(cats_path+'/'+i))
y2=[0]*1000

# %%
# Getting all the data together
X.extend(x2)
y.extend(y2)
X=np.array(X)
y=np.array(y)
X2=X/255

# %% [markdown]
# #### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split( X2, y, test_size=0.15, random_state=42 )

# %% [markdown]
# #### model

# %%
model=M.Sequential()
model.add(L.Reshape((150,150,1)))
model.add(L.Conv2D(kernel_size=(3,3),filters=32,input_shape=(150,150),activation='relu'))
model.add(L.MaxPool2D(pool_size=(2,2)))
model.add(L.Conv2D(kernel_size=(3,3),filters=64,activation='relu'))
model.add(L.MaxPool2D(pool_size=(2,2)))
model.add(L.Flatten())
model.add(L.Dense(1000,activation='tanh'))
model.add(L.Dense(100,'relu'))
model.add(L.Dense(2,activation='softmax'))

# %% [markdown]
# #### Compiling

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# #### Training

# %%
model.fit(X_train,y_train,epochs=20,validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 54/54 [==============================] - 7s 80ms/step - loss: 1.4877 - accuracy: 0.5088 - val_loss: 0.6912 - val_accuracy: 0.5700
# Epoch 2/20
# 54/54 [==============================] - 4s 70ms/step - loss: 0.6855 - accuracy: 0.5612 - val_loss: 0.6954 - val_accuracy: 0.5400
# Epoch 3/20
# 54/54 [==============================] - 4s 69ms/step - loss: 0.5742 - accuracy: 0.7041 - val_loss: 0.7850 - val_accuracy: 0.5300
# Epoch 4/20
# 54/54 [==============================] - 4s 69ms/step - loss: 0.2445 - accuracy: 0.9088 - val_loss: 1.0259 - val_accuracy: 0.6000
# Epoch 5/20
# 54/54 [==============================] - 4s 70ms/step - loss: 0.0524 - accuracy: 0.9876 - val_loss: 1.6691 - val_accuracy: 0.5500
# Epoch 6/20
# 54/54 [==============================] - 4s 70ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.7716 - val_accuracy: 0.5800
# Epoch 7/20
# 54/54 [==============================] - 4s 70ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.8833 - val_accuracy: 0.5700
# Epoch 8/20
# 54/54 [==============================] - 4s 70ms/step - loss: 7.0246e-04 - accuracy: 1.0000 - val_loss: 2.1417 - val_accuracy: 0.5700
# Epoch 9/20
# 54/54 [==============================] - 4s 70ms/step - loss: 2.2506e-04 - accuracy: 1.0000 - val_loss: 2.5805 - val_accuracy: 0.5533
# Epoch 10/20
# 54/54 [==============================] - 4s 70ms/step - loss: 4.5297e-05 - accuracy: 1.0000 - val_loss: 2.9153 - val_accuracy: 0.5700
# Epoch 11/20
# 54/54 [==============================] - 4s 70ms/step - loss: 1.6986e-05 - accuracy: 1.0000 - val_loss: 3.0961 - val_accuracy: 0.5700
# Epoch 12/20
# 54/54 [==============================] - 4s 70ms/step - loss: 1.0387e-05 - accuracy: 1.0000 - val_loss: 3.2227 - val_accuracy: 0.5700
# Epoch 13/20
# 54/54 [==============================] - 4s 70ms/step - loss: 7.2420e-06 - accuracy: 1.0000 - val_loss: 3.3165 - val_accuracy: 0.5667
# Epoch 14/20
# 54/54 [==============================] - 4s 70ms/step - loss: 5.5037e-06 - accuracy: 1.0000 - val_loss: 3.4037 - val_accuracy: 0.5700
# Epoch 15/20
# 54/54 [==============================] - 4s 70ms/step - loss: 4.3166e-06 - accuracy: 1.0000 - val_loss: 3.4664 - val_accuracy: 0.5633
# Epoch 16/20
# 54/54 [==============================] - 4s 70ms/step - loss: 3.5668e-06 - accuracy: 1.0000 - val_loss: 3.5243 - val_accuracy: 0.5633
# Epoch 17/20
# 54/54 [==============================] - 4s 70ms/step - loss: 2.9804e-06 - accuracy: 1.0000 - val_loss: 3.5831 - val_accuracy: 0.5667
# Epoch 18/20
# 54/54 [==============================] - 4s 70ms/step - loss: 2.2971e-06 - accuracy: 1.0000 - val_loss: 3.6248 - val_accuracy: 0.5667
# Epoch 19/20
# 54/54 [==============================] - 4s 70ms/step - loss: 1.9174e-06 - accuracy: 1.0000 - val_loss: 3.6724 - val_accuracy: 0.5667
# Epoch 20/20
# 54/54 [==============================] - 4s 70ms/step - loss: 1.6110e-06 - accuracy: 1.0000 - val_loss: 3.7133 - val_accuracy: 0.5633

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 150, 150, 1)       0
#
#  conv2d_2 (Conv2D)           (None, 148, 148, 32)      320
#
#  max_pooling2d_2 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 82944)             0
#
#  dense_3 (Dense)             (None, 1000)              82945000
#
#  dense_4 (Dense)             (None, 100)               100100
#
#  dense_5 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 83,064,118
# Trainable params: 83,064,118
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.models.save_model(model,'./save_models/mask_model.h5')

# %% [markdown]
# #### predictions

# %%
def make_predictions(path) :
    l=['Cats','Dogs']
    print('The masked image is :')
    arr=make_mask(path,print_plot=True)
    arr=np.array(arr)
    arr=arr.reshape(1,150,150)
    clas=np.argmax(model.predict(arr),axis=-1)
    print(l[clas[0]])

# %%
make_predictions('./datasets/dog_vs_cat/test_set/dogs/dog.4005.jpg')
# Out:
# The masked image is :
# 1/1 [==============================] - 0s 371ms/step
# Dogs

# %%
make_predictions('./datasets/dog_vs_cat/test_set/cats/cat.4008.jpg')
# Out:
# The masked image is :
# 1/1 [==============================] - 0s 20ms/step
# Cats
